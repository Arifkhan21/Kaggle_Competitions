# %%
import pandas as pd 
import numpy as np
from sklearn.metrics import log_loss
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import LabelEncoder
from mpl_toolkits.mplot3d import Axes3D

# %%
data_train = pd.read_csv('train.csv')
data_test = pd.read_csv('test.csv')

# %%
pop_id = data_test.pop('id')
data_train.head()
# Out:
#    id                species   margin1   margin2   margin3   margin4  \
# 0   1            Acer_Opalus  0.007812  0.023438  0.023438  0.003906
# 1   2  Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625
# 2   3   Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812
# 3   5        Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859
# 4   6     Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766
#
#     margin5   margin6   margin7  margin8  ...  texture55  texture56  \
# 0  0.011719  0.009766  0.027344      0.0  ...   0.007812   0.000000
# 1  0.025391  0.001953  0.019531      0.0  ...   0.000977   0.000000
# 2  0.003906  0.005859  0.068359      0.0  ...   0.154300   0.000000
# 3  0.021484  0.019531  0.023438      0.0  ...   0.000000   0.000977
# 4  0.013672  0.015625  0.005859      0.0  ...   0.096680   0.000000
#
#    texture57  texture58  texture59  texture60  texture61  texture62  \
# 0   0.002930   0.002930   0.035156        0.0        0.0   0.004883
# 1   0.000000   0.000977   0.023438        0.0        0.0   0.000977
# 2   0.005859   0.000977   0.007812        0.0        0.0   0.000000
# 3   0.000000   0.000000   0.020508        0.0        0.0   0.017578
# 4   0.021484   0.000000   0.000000        0.0        0.0   0.000000
#
#    texture63  texture64
# 0   0.000000   0.025391
# 1   0.039062   0.022461
# 2   0.020508   0.002930
# 3   0.000000   0.047852
# 4   0.000000   0.031250
#
# [5 rows x 194 columns]

# %%
ID = data_train.pop('id').values.tolist()
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Columns: 193 entries, species to texture64
# dtypes: float64(192), object(1)
# memory usage: 1.5+ MB

# %%
species = data_train['species']
species = np.array(species)
species = np.unique(species,return_counts=True)
print("Number of Species : "+str(species[0].shape[0]))
# Out:
# Number of Species : 99

# %%
from sklearn.model_selection import train_test_split
y_train = data_train.pop('species')
x_train = data_train

print(y_train.shape)
print(x_train.shape)

x_train,x_test,y_train,y_test = train_test_split(x_train,y_train,test_size=0.2)
# Out:
# (990,)
# (990, 192)

# %% [markdown]
# ## Testing Some Sklearn Models on the Dataset

# %%
from sklearn.metrics import accuracy_score
names = []
accuracies = []

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
knn_preds = knn.predict(x_test)
acc = accuracy_score(y_test,knn_preds)
print('Accuracy from KNN: {}'.format(acc))
accuracies.append(acc)
names.append(knn.__class__.__name__)
# Out:
# Accuracy from KNN: 0.8787878787878788

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc_preds = dtc.predict(x_test)
acc = accuracy_score(y_test,dtc_preds)
print('Accuracy from Decision Tree: {}'.format(acc))
accuracies.append(acc)
names.append(dtc.__class__.__name__)
# Out:
# Accuracy from Decision Tree: 0.6717171717171717

# %% [markdown]
#  ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf= RandomForestClassifier()
rf.fit(x_train,y_train)
rf_preds = rf.predict(x_test)
acc = accuracy_score(y_test,rf_preds)
print('Accuracy from Random Forest: {}'.format(acc))
accuracies.append(acc)
names.append(rf.__class__.__name__)
# Out:
# Accuracy from Random Forest: 0.8383838383838383
# /usr/local/lib/python3.5/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

nb= GaussianNB()
nb.fit(x_train,y_train)
nb_preds = nb.predict(x_test)
acc = accuracy_score(y_test,nb_preds)
print('Accuracy from Naive Bayes: {}'.format(acc))
accuracies.append(acc)
names.append(nb.__class__.__name__)
# Out:
# Accuracy from Naive Bayes: 0.5404040404040404

# %% [markdown]
# ## Linear Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 

lda= LinearDiscriminantAnalysis()
lda.fit(x_train,y_train)
lda_preds = lda.predict(x_test)
acc = accuracy_score(y_test,lda_preds)
print('Accuracy from LDA: {}'.format(acc))
accuracies.append(acc)
names.append(lda.__class__.__name__)
# Out:
# Accuracy from LDA: 0.9646464646464646
# /usr/local/lib/python3.5/dist-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier 

gb= GradientBoostingClassifier()
gb.fit(x_train,y_train)
gb_preds = gb.predict(x_test)
acc = accuracy_score(y_test,gb_preds)
print('Accuracy from Gradient Boosting: {}'.format(acc))
accuracies.append(acc)
names.append(gb.__class__.__name__)
# Out:
# Accuracy from Gradient Boosting: 0.5454545454545454

# %%
import seaborn as sns

plt.figure(figsize=(10,5))
sns.set_color_codes("muted")
sns.barplot(x=accuracies, y=names, color="b")
plt.xlabel('Accuracy')
plt.ylabel('Classifier Names')
# Out:
# Text(0, 0.5, 'Classifier Names')

# %% [markdown]
# Linear Discriminant Analysis works great with the data but we will go for neural network in the later part of notebook

# %% [markdown]
#  ## Visualization of Data After Dimensionality Reduction Using PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)
pca.fit(x_train)
Trans = pca.transform(x_train)

# %%
le = LabelEncoder()
lf = le.fit(y_train)
y_train = lf.transform(y_train)
print(y_train.shape)
# Out:
# (792,)

# %% [markdown]
# Visualising Using Matplotlib 3d visualization

# %%
def plot3D(Trans,y):
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111,projection='3d')
    ax.scatter(xs=Trans[:,0],ys=Trans[:,1],zs=Trans[:,2],c=y, cmap = 'Accent',marker='o')

# %%
plot3D(Trans,y_train)

# %% [markdown]
#  ## Visualization of Data After Dimensionality Reduction Using ISO

# %%
from sklearn.manifold import Isomap

# %%
iso = Isomap(n_components=3,n_neighbors=5)
iso.fit(x_train)
iso_trans = iso.transform(x_train)

# %%
plot3D(iso_trans,y_train)

# %% [markdown]
# ## Using KNN on 3-Dimentional Data and Checking Performance, Variance Retained

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)

# %%
#PCA Transform
knn.fit(Trans,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
print('Train LogLoss: {}'.format(log_loss(y_train,knn.predict_proba(Trans))))
# Out:
# Train LogLoss: 0.9412504817408407

# %%
knn.score(Trans,y_train)
# Out:
# 0.5747474747474748

# %%
knn_full = KNeighborsClassifier()
knn_full.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
print('Train LogLoss: {}'.format(log_loss(y_train,knn_full.predict_proba(x_train))))
# Out:
# Train LogLoss: 0.23643764662397035

# %%
knn_full.score(x_train,y_train)
# Out:
# 0.9292929292929293

# %% [markdown]
# Looks like keeping the features is more efficient as PCA is not retaining the most of the variance of data thus KNN not performing well on reduced dimensionality data.

# %%
print ('Variance retained: {}'.format(pca.explained_variance_ratio_.sum()))
# Out:
# Variance retained: 0.3384071957375884

# %% [markdown]
# Her We can see that 3-features can define 33% of the dataset alone as given by PCA (insight driven from variance retained)

# %% [markdown]
# ## Neural Network Model

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
model = Sequential()
model.add(Dense(1024,input_dim=192))
model.add(Dropout(0.2))
model.add(Activation('sigmoid'))
model.add(Dense(512))
model.add(Dropout(0.3))
model.add(Activation('sigmoid'))
model.add(Dense(99))
model.add(Activation('softmax'))

# %%
data_train=pd.read_csv('train.csv')
data_train.pop('id')
y_train = data_train.pop('species')
x_train = data_train
y_train.head()
y_train=y_train.values
x_train=x_train.values
lf = le.fit(y_train)
y_train=lf.transform(y_train)

# %%
y_categ = to_categorical(y_train)
x_norm = StandardScaler().fit(x_train).transform(x_train)

# %%
x_tra,x_test,y_tra,y_test = train_test_split(x_norm,y_categ,test_size=0.2)

# %%
print(x_tra.shape,x_test.shape)
print(y_tra.shape,y_test.shape)
# Out:
# (792, 192) (198, 192)
# (792, 99) (198, 99)

# %%
model.compile(loss='categorical_crossentropy',optimizer='rmsprop')

# %%
history = model.fit(x_tra,y_tra,batch_size=128,epochs=100,shuffle=True,verbose=1)
# Out:
# Epoch 1/100
# 792/792 [==============================] - 1s 670us/step - loss: 4.7975
# Epoch 2/100
# 792/792 [==============================] - 0s 172us/step - loss: 4.4071
# Epoch 3/100
# 792/792 [==============================] - 0s 163us/step - loss: 4.1519
# Epoch 4/100
# 792/792 [==============================] - 0s 168us/step - loss: 3.8860
# Epoch 5/100
# 792/792 [==============================] - 0s 163us/step - loss: 3.6445
# Epoch 6/100
# 792/792 [==============================] - 0s 157us/step - loss: 3.3907
# Epoch 7/100
# 792/792 [==============================] - 0s 160us/step - loss: 3.1811
# Epoch 8/100
# 792/792 [==============================] - 0s 159us/step - loss: 2.9654
# Epoch 9/100
# 792/792 [==============================] - 0s 165us/step - loss: 2.7654
# Epoch 10/100
# 792/792 [==============================] - 0s 177us/step - loss: 2.5382
# Epoch 11/100
# 792/792 [==============================] - 0s 182us/step - loss: 2.3446
# Epoch 12/100
# 792/792 [==============================] - 0s 185us/step - loss: 2.1835
# Epoch 13/100
# 792/792 [==============================] - 0s 190us/step - loss: 2.0102
# Epoch 14/100
# 792/792 [==============================] - 0s 189us/step - loss: 1.8158
# Epoch 15/100
# 792/792 [==============================] - 0s 184us/step - loss: 1.6577
# Epoch 16/100
# 792/792 [==============================] - 0s 167us/step - loss: 1.5303
# Epoch 17/100
# 792/792 [==============================] - 0s 164us/step - loss: 1.3966
# Epoch 18/100
# 792/792 [==============================] - 0s 166us/step - loss: 1.2701
# Epoch 19/100
# 792/792 [==============================] - 0s 163us/step - loss: 1.1387
# Epoch 20/100
# 792/792 [==============================] - 0s 166us/step - loss: 1.0480
# Epoch 21/100
# 792/792 [==============================] - 0s 179us/step - loss: 0.9441
# Epoch 22/100
# 792/792 [==============================] - 0s 175us/step - loss: 0.8433
# Epoch 23/100
# 792/792 [==============================] - 0s 173us/step - loss: 0.7620
# Epoch 24/100
# 792/792 [==============================] - 0s 182us/step - loss: 0.6870
# Epoch 25/100
# 792/792 [==============================] - 0s 198us/step - loss: 0.6309
# Epoch 26/100
# 792/792 [==============================] - 0s 192us/step - loss: 0.5718
# Epoch 27/100
# 792/792 [==============================] - 0s 174us/step - loss: 0.5036
# Epoch 28/100
# 792/792 [==============================] - 0s 168us/step - loss: 0.4573
# Epoch 29/100
# 792/792 [==============================] - 0s 197us/step - loss: 0.4014
# Epoch 30/100
# 792/792 [==============================] - 0s 164us/step - loss: 0.3633
# Epoch 31/100
# 792/792 [==============================] - 0s 168us/step - loss: 0.3227
# Epoch 32/100
# 792/792 [==============================] - 0s 174us/step - loss: 0.2891
# Epoch 33/100
# 792/792 [==============================] - 0s 173us/step - loss: 0.2680
# Epoch 34/100
# 792/792 [==============================] - 0s 182us/step - loss: 0.2375
# Epoch 35/100
# Epoch 78/100
# 792/792 [==============================] - 0s 162us/step - loss: 0.0016
# Epoch 79/100
# 792/792 [==============================] - 0s 190us/step - loss: 0.0021
# Epoch 80/100
# 792/792 [==============================] - 0s 186us/step - loss: 0.0011
# Epoch 81/100
# 792/792 [==============================] - 0s 178us/step - loss: 0.0011
# Epoch 82/100
# 792/792 [==============================] - 0s 180us/step - loss: 0.0011
# Epoch 83/100
# 792/792 [==============================] - 0s 180us/step - loss: 8.1015e-04
# Epoch 84/100
# 792/792 [==============================] - 0s 198us/step - loss: 7.5842e-04
# Epoch 85/100
# 792/792 [==============================] - 0s 178us/step - loss: 6.6489e-04
# Epoch 86/100
# 792/792 [==============================] - 0s 171us/step - loss: 6.2637e-04
# Epoch 87/100
# 792/792 [==============================] - 0s 165us/step - loss: 5.0262e-04
# Epoch 88/100
# 792/792 [==============================] - 0s 169us/step - loss: 4.9318e-04
# Epoch 89/100
# 792/792 [==============================] - 0s 166us/step - loss: 5.3695e-04
# Epoch 90/100
# 792/792 [==============================] - 0s 164us/step - loss: 3.9267e-04
# Epoch 91/100
# 792/792 [==============================] - 0s 171us/step - loss: 3.4889e-04
# Epoch 92/100
# 792/792 [==============================] - 0s 167us/step - loss: 2.8908e-04
# Epoch 93/100
# 792/792 [==============================] - 0s 168us/step - loss: 2.4072e-04
# Epoch 94/100
# 792/792 [==============================] - 0s 174us/step - loss: 2.6068e-04
# Epoch 95/100
# 792/792 [==============================] - 0s 174us/step - loss: 1.9929e-04
# Epoch 96/100
# 792/792 [==============================] - 0s 169us/step - loss: 1.9799e-04
# Epoch 97/100
# 792/792 [==============================] - 0s 176us/step - loss: 1.5200e-04
# Epoch 98/100
# 792/792 [==============================] - 0s 172us/step - loss: 1.5243e-04
# Epoch 99/100
# 792/792 [==============================] - 0s 174us/step - loss: 1.2689e-04
# Epoch 100/100
# 792/792 [==============================] - 0s 170us/step - loss: 1.1104e-04

# %%
score = model.evaluate(x_test,y_test)
print('CV Score: {}'.format(round(score,3)))
# Out:
# 198/198 [==============================] - 0s 725us/step
# CV Score: 0.167

# %%
preds = model.predict(x_test,verbose=1)
# Out:
# 198/198 [==============================] - 0s 698us/step

# %%
from sklearn.metrics import accuracy_score
temp_y_true=[]
temp_y_pred=[]
for ix in range(0,y_test.shape[0]):
    temp_y_pred.append(np.argmax(preds[ix]))
    temp_y_true.append(np.argmax(y_test[ix]))
print('Accuracy: {}'.format(accuracy_score(temp_y_true,temp_y_pred)))
# Out:
# Accuracy: 0.9747474747474747

# %%
fig = plt.figure(figsize=(20,10))
plt.plot(history.history['loss'], 'o-')
plt.xlabel('Number of iteration')
plt.ylabel('Crossentropy Loss')
# Out:
# Text(0, 0.5, 'Crossentropy Loss')

# %% [markdown]
# Her we Can see neural network is giving best reults on the actual training data. Though 20% of which was kept unseen by the model but the actual testing data is not labelled in te dataset and kaggle only has the actual labelled test data. Although our model didnt overfit on the training data since it gave quite goot accuracy on test data shuffled out by train_test_split. Lets see the final model graph.

# %%
accuracies.append(accuracy_score(temp_y_true,temp_y_pred))
names.append('Neural Network')

# %%
plt.figure(figsize=(10,5))
sns.set_color_codes("muted")
sns.barplot(x=accuracies, y=names, data=log, color="b")
plt.xlabel('Accuracy')
plt.ylabel('Classifier Names')
# Out:
# Text(0, 0.5, 'Classifier Names')
